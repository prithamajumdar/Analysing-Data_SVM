# %% [markdown]
# ## Importing required packages

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC

# %% [markdown]
# ## Loading file

# %%
df = pd.read_csv(file_path)

# %%
len(df)
# Out:
# 100

# %%
df.head()
# Out:
#    No                                          Sentences  \
# 0   1                       Tom is as fast as a leopard.
# 1   2  But he’s no fool, even if he is as obstinate a...
# 2   3                       I was as cool as a cucumber.
# 3   4  He paid as much as a million dollars for the p...
# 4   5  The wicked flee when no one pursues; but the r...
#
#   Subject of comparison Object of comparison       Nature  \
# 0                   Tom            a leopard  Qualitative
# 1                    He               a mule  Qualitative
# 2                     I             cucumber  Qualitative
# 3                    He                    -            -
# 4             Righteous               a lion  Qualitative
#
#                                        Categories  \
# 0  Different basic level category (human, animal)
# 1  Different basic level category (human, animal)
# 2   Different basic level category (human, fruit)
# 3                                               -
# 4  Different basic level category (human, animal)
#
#               Feature matching      Symmetry  \
# 0   More prominent differences  Asymmetrical
# 1  More prominent differences   Asymmetrical
# 2   More prominent differences  Asymmetrical
# 3                            -             -
# 4   More prominent differences  Asymmetrical
#
#                                 Salience Broad, unifying concept  \
# 0  High salience in object of comparison              Meaningful
# 1  High salience in object of comparison              Meaningful
# 2  High salience in object of comparison              Meaningful
# 3                                      -                       -
# 4  High salience in object of comparison              Meaningful
#
#   Domain incongruence            Gold
# 0            Distinct          Simile
# 1            Distinct          Simile
# 2            Distinct          Simile
# 3                   -  Not Applicable
# 4            Distinct          Simile

# %% [markdown]
# ## Preparing the dataset

# %%
df= df[["Sentences", "Gold"]]

# %%
df
# Out:
#                                             Sentences            Gold
# 0                        Tom is as fast as a leopard.          Simile
# 1   But he’s no fool, even if he is as obstinate a...          Simile
# 2                        I was as cool as a cucumber.          Simile
# 3   He paid as much as a million dollars for the p...  Not Applicable
# 4   The wicked flee when no one pursues; but the r...          Simile
# ..                                                ...             ...
# 95         He always keeps his room as neat as a pin.          Simile
# 96              He is as stubborn as a Missouri Mule.          Simile
# 97               The surface was as flat as a mirror.      Comparison
# 98  It allows very poor people, who don't qualify ...  Not Applicable
# 99                        Tom is as gentle as a lamb.          Simile
#
# [100 rows x 2 columns]

# %%
print(df['Gold'].unique())
# Out:
# ['Simile' 'Not Applicable' 'Comparison']

# %% [markdown]
# ## Coverting into labels

# %%
new_df= df.copy()

# %%
new_df.loc[new_df['Gold'] == 'Simile', 'Gold'] = 0
new_df.loc[new_df['Gold'] == 'Comparison', 'Gold'] = 1
new_df.loc[new_df['Gold'] == 'Not Applicable', 'Gold'] = 2

# %%
new_df
# Out:
#                                             Sentences Gold
# 0                        Tom is as fast as a leopard.    0
# 1   But he’s no fool, even if he is as obstinate a...    0
# 2                        I was as cool as a cucumber.    0
# 3   He paid as much as a million dollars for the p...    2
# 4   The wicked flee when no one pursues; but the r...    0
# ..                                                ...  ...
# 95         He always keeps his room as neat as a pin.    0
# 96              He is as stubborn as a Missouri Mule.    0
# 97               The surface was as flat as a mirror.    1
# 98  It allows very poor people, who don't qualify ...    2
# 99                        Tom is as gentle as a lamb.    0
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Splitting into train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(new_df['Sentences'], new_df['Gold'], test_size= 0.2, random_state= 42)

# %% [markdown]
# Material on Understanding Tf-Idf - https://www.geeksforgeeks.org/understanding-tf-idf-term-frequency-inverse-document-frequency/
#
# Material on Understanding BOW- https://www.geeksforgeeks.org/bag-of-word-and-frequency-count-in-text-using-sklearn/?ref=next_article_top

# %% [markdown]
# ## Vectorization using Bag-Of-Words with word unigrams, bigrams and character unigrams and bigrams

# %%
word_vectorizer= CountVectorizer(ngram_range=(1,2), analyzer='word')
char_vectorizer= CountVectorizer(ngram_range=(1,2), analyzer='char')

# %% [markdown]
# ## Fit and transform

# %% [markdown]
# Source for more on fit(), transform() and fit_transform()- https://www.analyticsvidhya.com/blog/2021/04/difference-between-fit-transform-fit_transform-methods-in-scikit-learn-with-python-code/

# %%
word_vectorizer.fit(X_train)
# Out:
# CountVectorizer(ngram_range=(1, 2))

# %%
word_vectorizer.vocabulary_
# Out:
# {'heard': 644,
#  'her': 656,
#  'speaking': 1203,
#  'english': 465,
#  'as': 94,
#  'fluently': 523,
#  'an': 43,
#  'american': 40,
#  'heard her': 646,
#  'her speaking': 660,
#  'speaking english': 1204,
#  'english as': 466,
#  'as fluently': 131,
#  'fluently as': 524,
#  'as an': 98,
#  'an american': 44,
#  'he': 621,
#  'is': 714,
#  'nutty': 932,
#  'fruitcake': 557,
#  'he is': 628,
#  'is as': 715,
#  'as nutty': 172,
#  'nutty as': 933,
#  'as fruitcake': 137,
#  'this': 1349,
#  'child': 332,
#  'gentle': 562,
#  'lamb': 772,
#  'today': 1380,
#  'this child': 1350,
#  'child is': 333,
#  'as gentle': 138,
#  'gentle as': 563,
#  'as lamb': 152,
#  'lamb today': 773,
#  'frederick': 542,
#  'looked': 824,
#  'white': 1461,
#  'sheet': 1159,
#  'said': 1128,
#  'one': 972,
#  'old': 962,
#  'woman': 1490,
#  'and': 50,
#  'the': 1269,
#  'crowd': 395,
#  'parted': 1013,
#  'gentry': 564,
#  'carriage': 322,
#  'drove': 436,
#  'out': 992,
#  'of': 943,
#  'yard': 1510,
#  'frederick looked': 544,
#  'looked as': 825,
#  'as white': 219,
#  'white as': 1462,
#  'as sheet': 193,
#  'sheet said': 1160,
#  'said one': 1129,
#  'one old': 974,
#  'old woman': 967,
#  'woman and': 1491,
#  'and the': 73,
#  'the crowd': 1283,
#  'crowd parted': 396,
#  'parted as': 1014,
#  'as the': 209,
#  'the gentry': 1291,
#  'gentry carriage': 565,
#  'carriage drove': 323,
#  'drove out': 437,
#  'out of': 995,
#  'of the': 953,
#  'the yard': 1323,
#  'you': 1519,
#  'look': 822,
#  'pale': 1009,
#  'ghost': 572,
#  'you look': 1520,
#  'look as': 823,
#  'as pale': 175,
#  'pale as': 1010,
#  'as ghost': 139,
#  'without': 1485,
#  'his': 663,
#  'glasses': 575,
#  'blind': 268,
#  'bat': 239,
#  'without his': 1488,
#  'his glasses': 668,
#  'glasses he': 576,
#  'as blind': 104,
#  'blind as': 269,
#  'as bat': 100,
#  'bread': 281,
#  'hard': 609,
#  'rock': 1108,
#  'this old': 1351,
#  'old bread': 963,
#  'bread is': 282,
#  'as hard': 143,
#  'hard as': 610,
#  'as rock': 188,
#  'stubborn': 1239,
#  'missouri': 876,
#  'mule': 892,
#  'as stubborn': 207,
#  'stubborn as': 1240,
#  'as missouri': 164,
#  'missouri mule': 877,
#  'healthy': 641,
#  'horse': 676,
#  'as healthy': 144,
#  'healthy as': 643,
#  'as horse': 146,
#  'nod': 915,
#  'good': 581,
#  'wink': 1475,
#  'to': 1365,
#  'nod is': 916,
#  'as good': 141,
#  'good as': 582,
#  'as wink': 220,
#  'wink to': 1476,
#  'to blind': 1367,
#  'blind horse': 270,
#  'am': 35,
#  'happy': 606,
#  'angel': 76,
#  'am as': 36,
#  'as happy': 142,
#  'happy as': 607,
#  'an angel': 45,
#  'miss': 872,
#  'mile': 866,
#  'miss is': 873,
#  'as mile': 161,
#  'nothing': 925,
#  'diamond': 421,
#  'nothing is': 926,
#  'as diamond': 121,
#  'ok': 960,
#  'll': 808,
#  'send': 1147,
#  'it': 735,
#  'soon': 1191,
#  'machine': 838,
#  'available': 233,
#  'ok ll': 961,
#  'll send': 810,
#  'send it': 1148,
#  'it out': 743,
#  'out as': 993,
#  'as soon': 200,
#  'soon as': 1192,
#  'as machine': 160,
#  'machine is': 839,
#  'is available': 716,
#  'fellow': 498,
#  'strong': 1237,
#  'oak': 934,
#  'the old': 1304,
#  'old fellow': 965,
#  'fellow is': 499,
#  'healthy and': 642,
#  'and as': 53,
#  'as strong': 206,
#  'strong as': 1238,
#  'an oak': 49,
#  'needy': 907,
#  'man': 846,
#  'who': 1463,
#  'oppresses': 979,
#  'poor': 1048,
#  'like': 794,
#  'driving': 434,
#  'rain': 1083,
#  'which': 1457,
#  'leaves': 786,
#  'no': 911,
#  'crops': 394,
#  'needy man': 908,
#  'man who': 848,
#  'who oppresses': 1466,
#  'oppresses the': 980,
#  'the poor': 1309,
#  'poor is': 1050,
#  'is like': 721,
#  'like driving': 796,
#  'driving rain': 435,
#  'rain which': 1084,
#  'which leaves': 1459,
#  'leaves no': 787,
#  'no crops': 912,
#  'caged': 304,
#  'cricket': 390,
#  'eats': 445,
#  'just': 753,
#  'much': 890,
#  'free': 545,
#  'caged cricket': 305,
#  'cricket eats': 391,
#  'eats just': 446,
#  'just as': 754,
#  'as much': 166,
#  'much as': 891,
#  'as free': 133,
#  'free cricket': 547,
#  'in': 688,
#  'my': 895,
#  'soul': 1195,
#  'there': 1336,
#  'are': 84,
#  'many': 849,
#  'places': 1034,
#  'that': 1259,
#  'cynical': 398,
#  'arrogant': 92,
#  'but': 291,
#  'at': 227,
#  'its': 746,
#  'core': 377,
#  'fears': 492,
#  'darkness': 407,
#  'week': 1448,
#  'sheep': 1158,
#  'in my': 696,
#  'my soul': 899,
#  'soul there': 1196,
#  'there are': 1337,
#  'are many': 87,
#  'many places': 852,
#  'places that': 1035,
#  'that are': 1260,
#  'are cynical': 86,
#  'cynical and': 399,
#  'and arrogant': 52,
#  'arrogant but': 93,
#  'but at': 292,
#  'at its': 228,
#  'its core': 747,
#  'core it': 378,
#  'it fears': 738,
#  'fears the': 493,
#  'the darkness': 1286,
#  'darkness and': 408,
#  'and is': 60,
#  'as week': 218,
#  'week as': 1449,
#  'as sheep': 192,
#  'keeps': 757,
#  'spry': 1207,
#  'young': 1522,
#  'enemies': 464,
#  'nothing keeps': 927,
#  'keeps man': 759,
#  'man as': 847,
#  'as spry': 201,
#  'spry as': 1208,
#  'as young': 224,
#  'young woman': 1523,
#  'and old': 68,
#  'old enemies': 964,
#  'their': 1325,
#  'lives': 806,
#  'about': 2,
#  'kosher': 766,
#  'pork': 1055,
#  'chop': 339,
#  'how': 677,
#  'critic': 392,
#  'described': 415,
#  'pair': 1008,
#  'their lives': 1326,
#  'lives are': 807,
#  'are about': 85,
#  'about as': 3,
#  'as kosher': 150,
#  'kosher as': 767,
#  'as pork': 181,
#  'pork chop': 1056,
#  'chop is': 340,
#  'is how': 720,
#  'how one': 678,
#  'one critic': 973,
#  'critic described': 393,
#  'described the': 416,
#  'the pair': 1307,
#  'tom': 1382,
#  'tom is': 1384,
#  'root': 1114,
#  'flower': 521,
#  'weak': 1444,
#  'baby': 234,
#  'finger': 509,
#  'the root': 1313,
#  'root of': 1115,
#  'of flower': 947,
#  'flower is': 522,
#  'as weak': 217,
#  'weak as': 1445,
#  'as baby': 99,
#  'baby finger': 235,
#  'roaring': 1106,
#  'lion': 799,
#  'on': 968,
#  'charging': 330,
#  'bear': 247,
#  'so': 1184,
#  'wicked': 1470,
#  'ruler': 1119,
#  'over': 998,
#  'helpless': 652,
#  'people': 1020,
#  'as roaring': 187,
#  'roaring lion': 1107,
#  'lion on': 800,
#  'on charging': 970,
#  'charging bear': 331,
#  'bear so': 248,
#  'so is': 1187,
#  'is wicked': 729,
#  'wicked ruler': 1471,
#  'ruler over': 1120,
#  'over helpless': 999,
#  'helpless people': 653,
#  'always': 33,
#  'room': 1110,
#  'neat': 905,
#  'pin': 1031,
#  'he always': 622,
#  'always keeps': 34,
#  'keeps his': 758,
#  'his room': 672,
#  'room as': 1111,
#  'as neat': 169,
#  'neat as': 906,
#  'as pin': 177,
#  'having': 619,
#  'eluded': 456,
#  'killers': 764,
#  'malaria': 842,
#  'aids': 18,
#  'should': 1164,
#  'not': 919,
#  'then': 1333,
#  'be': 240,
#  'killed': 762,
#  'prematurely': 1067,
#  'by': 297,
#  'cancer': 317,
#  'especially': 469,
#  'form': 536,
#  'could': 380,
#  'have': 615,
#  'been': 256,
#  'prevented': 1069,
#  'with': 1479,
#  'something': 1189,
#  'simple': 1168,
#  'affordable': 8,
#  'vaccine': 1416,
#  'having eluded': 620,
#  'eluded killers': 457,
#  'killers like': 765,
#  'like malaria': 797,
#  'malaria and': 843,
#  'and aids': 51,
#  'aids one': 19,
#  'one should': 975,
#  'should not': 1165,
#  'not then': 921,
#  'then be': 1334,
#  'be killed': 245,
#  'killed prematurely': 763,
#  'prematurely by': 1068,
#  'by cancer': 300,
#  'cancer especially': 318,
#  'especially form': 470,
#  'form of': 537,
#  'of cancer': 945,
#  'cancer that': 319,
#  'that could': 1262,
#  'could have': 382,
#  'have been': 616,
#  'been prevented': 257,
#  'prevented with': 1070,
#  'with something': 1481,
#  'something as': 1190,
#  'as simple': 195,
#  'simple and': 1169,
#  'as affordable': 95,
#  'affordable as': 9,
#  'as vaccine': 214,
#  'last': 776,
#  'time': 1359,
#  'saw': 1130,
#  'was': 1429,
#  'drunk': 438,
#  'skunk': 1170,
#  'the last': 1298,
#  'last time': 777,
#  'time saw': 1361,
#  'saw tom': 1132,
#  'tom he': 1383,
#  'he was': 633,
#  'was as': 1430,
#  'as drunk': 123,
#  'drunk as': 439,
#  'as skunk': 196,
#  'far': 487,
#  'politics': 1046,
#  'concerned': 363,
#  'still': 1223,
#  'innocent': 702,
#  'as far': 125,
#  'far as': 488,
#  'as politics': 179,
#  'politics is': 1047,
#  'is concerned': 717,
#  'concerned he': 364,
#  'he still': 632,
#  'still as': 1225,
#  'as innocent': 148,
#  'innocent as': 703,
#  'as child': 111,
#  'quiet': 1079,
#  'mouse': 887,
#  'll be': 809,
#  'be as': 241,
#  'as quiet': 183,
#  'quiet as': 1080,
#  'as mouse': 165,
#  'important': 686,
#  'counting': 383,
#  'stops': 1230,
#  'jack': 749,
#  'missing': 874,
#  'from': 554,
#  'hand': 603,
#  'important the': 687,
#  'the counting': 1281,
#  'counting stops': 384,
#  'stops as': 1231,
#  'as jack': 149,
#  'jack is': 750,
#  'is missing': 722,
#  'missing from': 875,
#  'from the': 556,
#  'the hand': 1293,
#  'giddy': 573,
#  'drunken': 440,
#  'as giddy': 140,
#  'giddy as': 574,
#  'as drunken': 124,
#  'drunken man': 441,
#  'didn': 422,
#  'watch': 1434,
#  'them': 1328,
#  'perched': 1023,
#  'alertly': 20,
#  'squirrel': 1209,
#  'bag': 236,
#  'radishes': 1082,
#  'but he': 293,
#  'he didn': 624,
#  'didn watch': 423,
#  'watch them': 1435,
#  'them he': 1330,
#  'he just': 629,
#  'just perched': 756,
#  'perched as': 1024,
#  'as alertly': 96,
#  'alertly as': 21,
#  'as squirrel': 202,
#  'squirrel over': 1210,
#  'over the': 1000,
#  'the bag': 1272,
#  'bag of': 237,
#  'of radishes': 951,
#  'paid': 1005,
#  'million': 867,
#  'dollars': 425,
#  'for': 532,
#  'painting': 1007,
#  'he paid': 631,
#  'paid as': 1006,
#  'as million': 162,
#  'million dollars': 868,
#  'dollars for': 426,
#  'for the': 534,
#  'the painting': 1306,
#  'yet': 1517,
#  'according': 4,
#  'world': 1495,
#  'health': 639,
#  'organization': 986,
#  'all': 24,
#  'three': 1355,
#  'countries': 385,
#  'worldwide': 1499,
#  'women': 1493,
#  'can': 313,
#  'expect': 479,
#  'outlive': 996,
#  'men': 860,
#  'up': 1408,
#  'seven': 1149,
#  'years': 1515,
#  'japan': 751,
#  'or': 981,
#  'little': 801,
#  'year': 1511,
#  'poorer': 1053,
#  'sub': 1243,
#  'saharan': 1126,
#  'africa': 10,
#  'and yet': 75,
#  'yet according': 1518,
#  'according to': 5,
#  'to the': 1379,
#  'the world': 1322,
#  'world health': 1497,
#  'health organization': 640,
#  'organization in': 987,
#  'in all': 689,
#  'all but': 25,
#  'but three': 296,
#  'three countries': 1356,
#  'countries worldwide': 387,
#  'worldwide women': 1500,
#  'women can': 1494,
#  'can expect': 316,
#  'expect to': 480,
#  'to outlive': 1372,
#  'outlive men': 997,
#  'men by': 861,
#  'by up': 303,
#  'up to': 1410,
#  'to seven': 1378,
#  'seven years': 1150,
#  'years in': 1516,
#  'in japan': 693,
#  'japan or': 752,
#  'or by': 982,
#  'by as': 298,
#  'as little': 155,
#  'little as': 802,
#  'as year': 223,
#  'year in': 1513,
#  'in the': 698,
#  'the poorer': 1310,
#  'poorer countries': 1054,
#  'countries of': 386,
#  'of sub': 952,
#  'sub saharan': 1244,
#  'saharan africa': 1127,
#  'mouth': 888,
#  'smoother': 1181,
#  'than': 1255,
#  'oil': 958,
#  'end': 462,
#  'she': 1155,
#  'bitter': 266,
#  'wormwood': 1501,
#  'sharp': 1153,
#  'two': 1398,
#  'edged': 451,
#  'sword': 1252,
#  'her mouth': 658,
#  'mouth is': 889,
#  'is smoother': 726,
#  'smoother than': 1182,
#  'than oil': 1258,
#  'oil but': 959,
#  'but in': 294,
#  'the end': 1289,
#  'end she': 463,
#  'she is': 1156,
#  'as bitter': 103,
#  'bitter as': 267,
#  'as wormwood': 222,
#  'wormwood and': 1502,
#  'as sharp': 191,
#  'sharp as': 1154,
#  'as two': 213,
#  'two edged': 1399,
#  'edged sword': 452,
#  'hungry': 679,
#  'as hungry': 147,
#  'hungry as': 680,
#  'as bear': 101,
#  'rat': 1089,
#  'as poor': 180,
#  'poor as': 1049,
#  'as rat': 185,
#  'better': 260,
#  'walks': 1425,
#  'integrity': 708,
#  'perverse': 1029,
#  'ways': 1440,
#  'rich': 1103,
#  'better is': 261,
#  'is the': 728,
#  'poor who': 1052,
#  'who walks': 1467,
#  'walks in': 1426,
#  'in his': 692,
#  'his integrity': 670,
#  'integrity than': 709,
#  'than he': 1256,
#  'he who': 635,
#  'who is': 1465,
#  'is perverse': 723,
#  'perverse in': 1030,
#  'his ways': 673,
#  'ways and': 1441,
#  'and he': 58,
#  'is rich': 725,
#  'russia': 1123,
#  'worry': 1503,
#  'us': 1413,
#  'attack': 231,
#  'against': 13,
#  'nuclear': 928,
#  'deterrent': 417,
#  'other': 990,
#  'defense': 413,
#  'assets': 225,
#  'relies': 1096,
#  'america': 37,
#  'growing': 589,
#  'stock': 1226,
#  'long': 820,
#  'range': 1085,
#  'precision': 1063,
#  'guided': 593,
#  'conventional': 371,
#  'weapons': 1446,
#  'would': 1507,
#  'devastating': 419,
#  'strike': 1236,
#  'many in': 851,
#  'in russia': 697,
#  'russia worry': 1125,
#  'worry that': 1504,
#  'that us': 1268,
#  'us attack': 1414,
#  'attack against': 232,
#  'against russia': 14,
#  'russia nuclear': 1124,
#  'nuclear deterrent': 930,
#  'deterrent and': 418,
#  'and other': 70,
#  'other defense': 991,
#  'defense assets': 414,
#  'assets that': 226,
#  'that relies': 1265,
#  'relies on': 1097,
#  'on america': 969,
#  'america growing': 38,
#  'growing stock': 590,
#  'stock of': 1227,
#  'of long': 949,
#  'long range': 821,
#  'range precision': 1086,
#  'precision guided': 1064,
#  'guided conventional': 594,
#  'conventional weapons': 372,
#  'weapons would': 1447,
#  'would be': 1508,
#  'as devastating': 120,
#  'devastating as': 420,
#  'as nuclear': 171,
#  'nuclear strike': 931,
#  'few': 502,
#  'treasures': 1390,
#  'worth': 1505,
#  'friend': 550,
#  'wise': 1477,
#  'helpful': 651,
#  'few treasures': 504,
#  'treasures are': 1391,
#  'are worth': 89,
#  'worth as': 1506,
#  'as friend': 135,
#  'friend who': 551,
#  'is wise': 730,
#  'wise and': 1478,
#  'and helpful': 59,
#  'politician': 1044,
#  'slippery': 1175,
#  'eel': 453,
#  'the politician': 1308,
#  'politician is': 1045,
#  'as slippery': 197,
#  'slippery as': 1176,
#  'an eel': 47,
#  'lake': 770,
#  'water': 1438,
#  'smooth': 1179,
#  'mirror': 871,
#  'the lake': 1297,
#  'lake water': 771,
#  'water is': 1439,
#  'as smooth': 199,
#  'smooth as': 1180,
#  'as mirror': 163,
#  'true': 1392,
#  'original': 988,
#  'thirteen': 1347,
#  'colonies': 358,
#  'were': 1450,
#  'loose': 828,
#  'federation': 496,
#  'americans': 41,
#  'considered': 367,
#  'themselves': 1331,
#  'citizens': 343,
#  'state': 1216,
#  'first': 510,
#  'second': 1140,
#  'late': 778,
#  'century': 326,
#  'after': 11,
#  'revolution': 1102,
#  'true america': 1393,
#  'america original': 39,
#  'original thirteen': 989,
#  'thirteen colonies': 1348,
#  'colonies were': 359,
#  'were loose': 1451,
#  'loose federation': 829,
#  'federation and': 497,
#  'and many': 64,
#  'many americans': 850,
#  'americans considered': 42,
#  'considered themselves': 368,
#  'themselves citizens': 1332,
#  'citizens of': 344,
#  'of their': 954,
#  'their state': 1327,
#  'state first': 1217,
#  'first and': 511,
#  'and of': 67,
#  'the us': 1321,
#  'us second': 1415,
#  'second as': 1141,
#  'as late': 154,
#  'late as': 779,
#  'as century': 110,
#  'century after': 327,
#  'after the': 12,
#  'the revolution': 1312,
#  'figment': 506,
#  'figure': 508,
#  'is figment': 719,
#  'figment as': 507,
#  'as figure': 129,
#  'if': 683,
#  'rising': 1104,
#  'sea': 1137,
#  'levels': 792,
#  'flood': 517,
#  'maldive': 844,
#  'islands': 731,
#  'effects': 454,
#  'climate': 351,
#  'change': 328,
#  'bomb': 271,
#  'even': 473,
#  'united': 1404,
#  'states': 1218,
#  'europe': 471,
#  'damage': 401,
#  'say': 1133,
#  'florida': 519,
#  'netherlands': 909,
#  'costly': 379,
#  'if rising': 685,
#  'rising sea': 1105,
#  'sea levels': 1139,
#  'levels flood': 793,
#  'flood the': 518,
#  'the maldive': 1299,
#  'maldive islands': 845,
#  'islands the': 732,
#  'the effects': 1288,
#  'effects of': 455,
#  'of climate': 946,
#  'climate change': 352,
#  'change would': 329,
#  'nuclear bomb': 929,
#  'bomb and': 272,
#  'and even': 57,
#  'even for': 474,
#  'the united': 1320,
#  'united states': 1405,
#  'states and': 1219,
#  'and europe': 56,
#  'europe the': 472,
#  'the damage': 1284,
#  'damage to': 402,
#  'to say': 1377,
#  'say florida': 1134,
#  'florida or': 520,
#  'or the': 983,
#  'the netherlands': 1302,
#  'netherlands could': 910,
#  'could be': 381,
#  'be just': 244,
#  'as costly': 115,
#  'statue': 1220,
#  'as still': 205,
#  'as statue': 204,
#  'had': 595,
#  'altered': 31,
#  'position': 1057,
#  'half': 599,
#  'lying': 834,
#  'arm': 90,
#  'flung': 525,
#  'round': 1117,
#  'withered': 1483,
#  'branch': 277,
#  'watched': 1436,
#  'unmoved': 1406,
#  'ranger': 1087,
#  'glided': 577,
#  'careful': 320,
#  'stride': 1234,
#  'calling': 306,
#  'noiselessly': 917,
#  'lynx': 836,
#  'entering': 467,
#  'hen': 654,
#  'roost': 1112,
#  'through': 1357,
#  'bushes': 289,
#  'almost': 29,
#  'overgrew': 1001,
#  'footpath': 531,
#  'all this': 26,
#  'this time': 1352,
#  'time frederick': 1360,
#  'frederick had': 543,
#  'had not': 597,
#  'not altered': 920,
#  'altered his': 32,
#  'his position': 671,
#  'position half': 1058,
#  'half lying': 602,
#  'lying his': 835,
#  'his arm': 664,
#  'arm flung': 91,
#  'flung round': 526,
#  'round withered': 1118,
#  'withered branch': 1484,
#  'branch he': 278,
#  'he watched': 634,
#  'watched unmoved': 1437,
#  'unmoved as': 1407,
#  'the ranger': 1311,
#  'ranger glided': 1088,
#  'glided with': 578,
#  'with the': 1482,
#  'the careful': 1278,
#  'careful stride': 321,
#  'stride of': 1235,
#  'of his': 948,
#  'his calling': 665,
#  'calling as': 307,
#  'as noiselessly': 170,
#  'noiselessly as': 918,
#  'as lynx': 159,
#  'lynx entering': 837,
#  'entering hen': 468,
#  'hen roost': 655,
#  'roost through': 1113,
#  'through the': 1358,
#  'the bushes': 1277,
#  'bushes which': 290,
#  'which almost': 1458,
#  'almost overgrew': 30,
#  'overgrew the': 1002,
#  'the footpath': 1290,
#  'what': 1452,
#  'twelve': 1396,
#  'signs': 1166,
#  'zodiac': 1526,
#  'order': 984,
#  'sun': 1245,
#  'passes': 1015,
#  'course': 388,
#  'um': 1400,
#  'let': 790,
#  'me': 857,
#  'think': 1342,
#  'minute': 869,
#  'thinking': 1345,
#  'got': 583,
#  'come': 360,
#  'quick': 1075,
#  'shot': 1163,
#  'what are': 1453,
#  'are the': 88,
#  'the twelve': 1319,
#  'twelve signs': 1397,
#  'signs of': 1167,
#  'the zodiac': 1324,
#  'zodiac in': 1527,
#  'the order': 1305,
#  'order in': 985,
#  'in which': 699,
#  'which the': 1460,
#  'the sun': 1317,
#  'sun passes': 1247,
#  'passes them': 1016,
#  'them by': 1329,
#  'by in': 301,
#  'the course': 1282,
#  'course of': 389,
#  'of year': 955,
#  'year um': 1514,
#  'um let': 1401,
#  'let me': 791,
#  'me think': 858,
#  'think for': 1343,
#  'for minute': 533,
#  'minute no': 870,
#  'no thinking': 914,
#  'thinking it': 1346,
#  'it got': 739,
#  'got to': 584,
#  'to come': 1368,
#  'come as': 361,
#  'as quick': 182,
#  'quick as': 1076,
#  'as shot': 194,
#  'looks': 826,
#  'the child': 1280,
#  'child looks': 334,
#  'looks as': 827,
#  'surface': 1250,
#  'flat': 513,
#  'the surface': 1318,
#  'surface was': 1251,
#  'as flat': 130,
#  'flat as': 514,
#  'he as': 623,
#  'bird': 264,
#  'free as': 546,
#  'as bird': 102,
#  'timid': 1363,
#  'as timid': 212,
#  'timid as': 1364,
#  'quaint': 1071,
#  '1933': 0,
#  'economic': 447,
#  'conference': 365,
#  'took': 1386,
#  'place': 1032,
#  'geological': 566,
#  'museum': 893,
#  'london': 818,
#  'kensington': 760,
#  'when': 1454,
#  'international': 710,
#  'cooperation': 375,
#  'seemed': 1142,
#  'alien': 22,
#  'fossilized': 540,
#  'dinosaur': 424,
#  'it is': 742,
#  'is quaint': 724,
#  'quaint that': 1072,
#  'that the': 1267,
#  'the 1933': 1270,
#  '1933 world': 1,
#  'world economic': 1496,
#  'economic conference': 448,
#  'conference took': 366,
#  'took place': 1387,
#  'place in': 1033,
#  'the geological': 1292,
#  'geological museum': 567,
#  'museum in': 894,
#  'in london': 695,
#  'london kensington': 819,
#  'kensington at': 761,
#  'at time': 230,
#  'time when': 1362,
#  'when international': 1455,
#  'international cooperation': 711,
#  'cooperation seemed': 376,
#  'seemed as': 1143,
#  'as alien': 97,
#  'alien as': 23,
#  ...}

# %%
char_vectorizer.fit(X_train)
# Out:
# CountVectorizer(analyzer='char', ngram_range=(1, 2))

# %%
char_vectorizer.vocabulary_
# Out:
# {'i': 222,
#  ' ': 0,
#  'h': 209,
#  'e': 150,
#  'a': 76,
#  'r': 363,
#  'd': 132,
#  's': 390,
#  'p': 345,
#  'k': 248,
#  'n': 296,
#  'g': 192,
#  'l': 259,
#  'f': 179,
#  'u': 436,
#  't': 415,
#  'y': 473,
#  'm': 280,
#  'c': 115,
#  '.': 59,
#  'i ': 223,
#  ' h': 11,
#  'he': 214,
#  'ea': 156,
#  'ar': 91,
#  'rd': 371,
#  'd ': 133,
#  'er': 170,
#  'r ': 364,
#  ' s': 22,
#  'sp': 407,
#  'pe': 351,
#  'ak': 86,
#  'ki': 252,
#  'in': 235,
#  'ng': 308,
#  'g ': 193,
#  ' e': 8,
#  'en': 167,
#  'gl': 202,
#  'li': 268,
#  'is': 239,
#  'sh': 400,
#  'h ': 210,
#  ' a': 4,
#  'as': 92,
#  's ': 391,
#  ' f': 9,
#  'fl': 186,
#  'lu': 276,
#  'ue': 442,
#  'nt': 315,
#  'tl': 427,
#  'ly': 279,
#  'y ': 474,
#  'an': 89,
#  'n ': 297,
#  'am': 88,
#  'me': 288,
#  'ri': 376,
#  'ic': 227,
#  'ca': 118,
#  'n.': 301,
#  'e ': 151,
#  ' i': 12,
#  ' n': 17,
#  'nu': 316,
#  'ut': 451,
#  'tt': 432,
#  'ty': 435,
#  'a ': 77,
#  'fr': 188,
#  'ru': 386,
#  'ui': 444,
#  'it': 240,
#  'tc': 423,
#  'ke': 251,
#  'e.': 155,
#  'b': 99,
#  'o': 321,
#  'th': 425,
#  'hi': 215,
#  ' c': 6,
#  'ch': 122,
#  'il': 233,
#  'ld': 265,
#  ' g': 10,
#  'ge': 199,
#  'le': 266,
#  ' l': 15,
#  'la': 264,
#  'mb': 287,
#  'b ': 100,
#  ' t': 23,
#  'to': 428,
#  'od': 329,
#  'da': 137,
#  'ay': 97,
#  'y.': 477,
#  '"': 34,
#  'w': 457,
#  ',': 47,
#  "'": 41,
#  'v': 452,
#  '"f': 36,
#  're': 372,
#  'ed': 159,
#  'de': 139,
#  'ck': 124,
#  'k ': 249,
#  'lo': 272,
#  'oo': 337,
#  'ok': 333,
#  ' w': 26,
#  'wh': 462,
#  'te': 424,
#  'ee': 160,
#  'et': 172,
#  't,': 419,
#  ',"': 49,
#  '" ': 35,
#  'sa': 396,
#  'ai': 85,
#  'id': 228,
#  ' o': 18,
#  'on': 336,
#  'ne': 306,
#  'ol': 334,
#  'wo': 465,
#  'om': 335,
#  'ma': 286,
#  'n,': 299,
#  ', ': 48,
#  'nd': 305,
#  'cr': 127,
#  'ro': 381,
#  'ow': 344,
#  'wd': 460,
#  ' p': 19,
#  'pa': 349,
#  'rt': 385,
#  'tr': 430,
#  'ry': 389,
#  "y'": 475,
#  "'s": 45,
#  'rr': 383,
#  'ia': 225,
#  'ag': 83,
#  ' d': 7,
#  'dr': 145,
#  'ov': 343,
#  've': 454,
#  'ou': 342,
#  't ': 416,
#  'of': 330,
#  'f ': 180,
#  ' y': 27,
#  'ya': 478,
#  'd.': 136,
#  'yo': 482,
#  'u ': 437,
#  'al': 87,
#  'gh': 200,
#  'ho': 216,
#  'os': 340,
#  'st': 410,
#  't.': 420,
#  'wi': 463,
#  'ss': 409,
#  'se': 399,
#  'es': 171,
#  's,': 393,
#  ' b': 5,
#  'bl': 109,
#  'ba': 104,
#  'at': 93,
#  'br': 111,
#  'ad': 81,
#  'ha': 213,
#  ' r': 21,
#  'oc': 328,
#  'k.': 250,
#  'tu': 433,
#  'ub': 439,
#  'bb': 105,
#  'bo': 110,
#  'or': 339,
#  'rn': 380,
#  ' m': 16,
#  'mi': 289,
#  'so': 406,
#  'ur': 449,
#  'mu': 293,
#  'ul': 445,
#  "i'": 224,
#  "'m": 44,
#  'm ': 281,
#  'lt': 275,
#  'hy': 221,
#  'rs': 384,
#  'no': 313,
#  'go': 205,
#  'nk': 310,
#  'o ': 322,
#  'ap': 90,
#  'pp': 357,
#  'py': 360,
#  'el': 165,
#  'ot': 341,
#  'di': 141,
#  'mo': 290,
#  '. ': 60,
#  "'l": 43,
#  'll': 270,
#  'l ': 260,
#  'ac': 80,
#  'av': 95,
#  'va': 453,
#  'ab': 79,
#  'fe': 183,
#  'w ': 458,
#  'oa': 326,
#  'dy': 149,
#  'op': 338,
#  'pr': 358,
#  'po': 356,
#  'ik': 232,
#  'iv': 241,
#  'vi': 455,
#  'ra': 369,
#  'ps': 359,
#  's.': 394,
#  'j': 244,
#  'ts': 431,
#  ' j': 13,
#  'ju': 247,
#  'us': 450,
#  'uc': 440,
#  'my': 295,
#  'ny': 319,
#  'pl': 355,
#  'ce': 121,
#  'cy': 131,
#  'yn': 481,
#  'ni': 309,
#  'og': 331,
#  'ga': 198,
#  'bu': 113,
#  'co': 126,
#  'e,': 154,
#  'rk': 377,
#  'kn': 254,
#  'we': 461,
#  'ek': 164,
#  'ep': 169,
#  'p.': 348,
#  ' k': 14,
#  'un': 447,
#  'em': 166,
#  'ie': 229,
#  '"t': 38,
#  'ei': 163,
#  'ir': 238,
#  'ko': 255,
#  'p,': 347,
#  'ti': 426,
#  'c ': 116,
#  'sc': 398,
#  'ib': 226,
#  'be': 106,
#  'r.': 367,
#  'by': 114,
#  'fi': 185,
#  'io': 236,
#  'rg': 374,
#  'gi': 201,
#  'r,': 365,
#  'lp': 273,
#  'eo': 168,
#  'lw': 278,
#  'wa': 459,
#  'ys': 483,
#  'pi': 354,
#  '–': 490,
#  'ud': 441,
#  'ds': 146,
#  'nc': 304,
#  ' –': 29,
#  '– ': 491,
#  'ec': 158,
#  'ci': 123,
#  'fo': 187,
#  'rm': 379,
#  'ev': 174,
#  'si': 401,
#  'im': 234,
#  'mp': 291,
#  'af': 82,
#  'ff': 184,
#  ' v': 25,
#  'cc': 119,
#  'aw': 96,
#  'sk': 402,
#  'ku': 257,
#  'fa': 182,
#  'cs': 128,
#  'd,': 134,
#  "e'": 153,
#  'nn': 312,
#  'q': 361,
#  ' q': 20,
#  'qu': 362,
#  ':': 70,
#  'ta': 422,
#  't:': 421,
#  ': ': 71,
#  'ja': 245,
#  'dd': 138,
#  ';': 72,
#  'dn': 143,
#  "n'": 298,
#  "'t": 46,
#  'm;': 285,
#  '; ': 73,
#  'rc': 370,
#  'sq': 408,
#  '..': 61,
#  'do': 144,
#  'g.': 197,
#  'z': 486,
#  'x': 469,
#  '-': 50,
#  'ye': 479,
#  'rl': 378,
#  'iz': 243,
#  'za': 487,
#  'hr': 217,
#  'dw': 148,
#  'ex': 176,
#  'xp': 472,
#  'ct': 129,
#  ' u': 24,
#  'up': 448,
#  'p ': 346,
#  'su': 411,
#  'b-': 102,
#  '-s': 57,
#  'ah': 84,
#  'a.': 78,
#  'sm': 404,
#  'oi': 332,
#  'l,': 262,
#  'bi': 107,
#  'mw': 294,
#  'rp': 382,
#  'tw': 434,
#  'o-': 324,
#  '-e': 52,
#  'dg': 140,
#  'sw': 412,
#  'hu': 220,
#  'gr': 206,
#  'lk': 269,
#  'ks': 256,
#  'eg': 162,
#  'y,': 476,
#  'rv': 387,
#  'h.': 212,
#  '’': 492,
#  'ns': 314,
#  'a’': 98,
#  '’s': 494,
#  'cl': 125,
#  'ef': 161,
#  'g-': 196,
#  '-r': 56,
#  'n-': 300,
#  '-g': 53,
#  'gu': 208,
#  'nv': 317,
#  'na': 303,
#  'ew': 175,
#  'pf': 352,
#  'fu': 190,
#  'l.': 263,
#  '!': 31,
#  'sl': 403,
#  'ip': 237,
#  'l!': 261,
#  'b.': 103,
#  'ig': 231,
#  'ms': 292,
#  'lv': 277,
#  'ze': 488,
#  'ft': 189,
#  'vo': 456,
#  'gm': 203,
#  'if': 230,
#  'ls': 274,
#  'b,': 101,
#  'eu': 173,
#  'o,': 323,
#  'n;': 302,
#  'lf': 267,
#  'yi': 480,
#  'g,': 195,
#  'h,': 211,
#  'nm': 311,
#  'nx': 318,
#  'x ': 470,
#  'ug': 443,
#  'lm': 271,
#  'tp': 429,
#  '?': 74,
#  '"w': 40,
#  'gn': 204,
#  ' z': 28,
#  'zo': 489,
#  'c,': 117,
#  'r?': 368,
#  '?"': 75,
#  ' -': 2,
#  '- ': 51,
#  ' "': 1,
#  '"u': 39,
#  'um': 446,
#  'm,': 282,
#  'e!': 152,
#  '!"': 33,
#  '"n': 37,
#  'g!': 194,
#  '! ': 32,
#  "t'": 418,
#  't!': 417,
#  'rf': 373,
#  '1': 63,
#  '9': 68,
#  '3': 65,
#  'ua': 438,
#  ' 1': 3,
#  '19': 64,
#  '93': 69,
#  '33': 67,
#  '3 ': 66,
#  'nf': 307,
#  'n’': 320,
#  'gt': 207,
#  'au': 94,
#  'ws': 467,
#  'fy': 191,
#  'rw': 388,
#  'ht': 219,
#  'sb': 397,
#  'ix': 242,
#  'xe': 471,
#  'ky': 258,
#  'ob': 327,
#  'bj': 108,
#  'je': 246,
#  'du': 147,
#  'wy': 468,
#  'yt': 484,
#  'm-': 283,
#  '-l': 54,
#  'hs': 218,
#  'dl': 142,
#  'kl': 253,
#  'bs': 112,
#  'wn': 464,
#  'o.': 325,
#  'e’': 178,
#  'd-': 135,
#  '-z': 58,
#  'cd': 120,
#  'pd': 350,
#  'rh': 375,
#  "s'": 392,
#  "' ": 42,
#  'ey': 177,
#  'm.': 284,
#  'cu': 130,
#  'sn': 405,
#  's;': 395,
#  'wr': 466,
#  "f'": 181,
#  'ph': 353,
#  'r-': 366,
#  '-n': 55,
#  'sy': 413,
#  '“': 495,
#  '”': 497,
#  'eb': 157,
#  'y’': 485,
#  ' “': 30,
#  '“s': 496,
#  '.”': 62,
#  '” ': 498,
#  's’': 414,
#  '’ ': 493}

# %%
# training data

X_train_word = word_vectorizer.transform(X_train)
X_train_char= char_vectorizer.transform(X_train)

# test data

X_test_word = word_vectorizer.transform(X_test)
X_test_char= char_vectorizer.transform(X_test)

# %%
y_train = y_train.astype('int')
y_test = y_test.astype('int')

# %% [markdown]
# ## SVM model training on word unigrams and bigrams

# %%
model = SVC(C=1.0, kernel='linear')

model.fit(X_train_word, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ## Accuracy on test set

# %%
predictions = model.predict(X_test_word)

# %%
print ("Accuracy:", accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.75

# %% [markdown]
# ## SVM model training on character unigrams and bigrams

# %%
model = SVC(C=1.0, kernel='linear')

model.fit(X_train_char, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ## Accuracy on test set

# %%
predictions = model.predict(X_test_char)

# %%
print ("Accuracy:", accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.55

# %% [markdown]
# ## Vectorization using Tf-Idf with word unigrams, bigrams

# %%
word_vectorizer= TfidfVectorizer(ngram_range=(1,2), analyzer='word')

# %% [markdown]
# ## Fit and transform

# %%
word_vectorizer.fit(X_train)
# Out:
# TfidfVectorizer(ngram_range=(1, 2))

# %%
# training data

X_train_word = word_vectorizer.transform(X_train)

# test data

X_test_word = word_vectorizer.transform(X_test)

# %%
y_train = y_train.astype('int')
y_test = y_test.astype('int')

# %% [markdown]
# ## SVM model training

# %%
model = SVC(C=1.0, kernel='linear')

model.fit(X_train_word, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ## Accuracy on test set

# %%
predictions = model.predict(X_test_word)

# %%
print ("Accuracy:", accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.75
